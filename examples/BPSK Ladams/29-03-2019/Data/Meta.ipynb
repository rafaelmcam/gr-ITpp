# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from import_me import *

# %%
array = readSave(readfileName = "2903bmp_high_samplerate.data")
plt.imshow(plt.imread("output.bmp"))

# %%
with open("red_dot.bmp", "rb") as f:
    tx_file = f.read()

tx = np.frombuffer(tx_file, dtype = np.uint8)

# %%
np.mean(np.equal(tx, array))
# Out:
# 1.0

# %%
with open("2903.data", "rb") as f:
    file = f.read()
    
    
rcv = np.frombuffer(file, dtype = np.uint8)


fig, ax = plt.subplots(2, 4, sharex=True, figsize=(20, 20))


#0, 1, 2
roll_cor = 2

for i in range(8):
    rcv_t = np.roll(np.packbits(np.roll(np.unpackbits(rcv), i)), roll_cor)
    ax[i//4, i%4].set_title(i)
    ax[i//4, i%4].imshow(rcv_t.reshape(256, 256, 3))

# %%
#esqueci do PACK no gnuradio
with open("bmpRTL.data", "rb") as f:
    file = f.read()
RTL = np.frombuffer(file, dtype = np.uint8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-74ed30c6d9f6> in <module>()
#       1 #esqueci do PACK no gnuradio
# ----> 2 with open("bmpRTL.data", "rb") as f:
#       3     file = f.read()
#       4 RTL = np.frombuffer(file, dtype = np.uint8)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bmpRTL.data'

# %%
RTL
